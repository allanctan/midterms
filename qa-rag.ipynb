# %%
import os
from typing import List

from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.chains import (
    ConversationalRetrievalChain,
)
from langchain.chat_models import ChatOpenAI

from langchain.docstore.document import Document
from langchain.memory import ChatMessageHistory, ConversationBufferMemory
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.vectorstores import Qdrant
from langchain.prompts import ChatPromptTemplate

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)

# %%
loader = PyMuPDFLoader(
    "data/meta10k.pdf",
)

documents = loader.load()
text=''
for doc in documents:
    text+=doc.page_content

# save text to file
with open('data/meta10k.txt', 'w') as f:
    f.write(text)

# %%
def init():
    loader = PyMuPDFLoader(
        "data/meta10k.pdf",
    )

    documents = loader.load()
    text=''
    for doc in documents:
        text+=doc.page_content

    # Split the text into chunks
    documents = text_splitter.split_documents(documents)

    # Create a Chroma vector store
    embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

    # Create a Chroma vector store
    embeddings = OpenAIEmbeddings()
    docsearch = Qdrant.from_documents(
        documents, embeddings, location=":memory:"
    )

    message_history = ChatMessageHistory()

    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True,
    )

    # Create a chain that uses the Chroma vector store
    chain = ConversationalRetrievalChain.from_llm(
        ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0, streaming=True),
        chain_type="stuff",
        retriever=docsearch.as_retriever(),
        memory=memory,
        return_source_documents=True,
    )
    return chain

chain = init()
# Out:
# /opt/miniconda3/envs/chainlit/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /opt/miniconda3/envs/chainlit/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
res = chain.invoke("Who are Meta's 'Directors' (i.e., members of the Board of Directors) ?")
print(res["answer"])
# Out:
# The Directors of Meta as of February 1, 2024, are Robert M. Kimmitt, Sheryl K. Sandberg, Tracey T. Travis, and Tony Xu.

# %%
import pandas as pd

# load testset from csv
testset = pd.read_csv("testset1.csv")
testset.head()
# Out:
#    Unnamed: 0                                           question  \
# 0           0  What was the total value of 'Cash and cash equ...
# 1           1  Who are Meta's 'Directors' (i.e., members of t...
# 2           2  How does the use of a common identifier help i...
# 3           3  How is net income used in the computation of d...
# 4           4  How does tax effects from share-based compensa...
#
#                                             contexts  \
# 0                                                NaN
# 1                                                NaN
# 2  ['mobile browser on a given day. We do not req...
# 3  ['The numerators and denominators of the basic...
# 4  ['Effective Tax Rate Items. Our effective tax ...
#
#                                         ground_truth evolution_type  \
# 0                                            $41.86B         simple
# 1  The Directors of Meta Platforms, Inc. listed o...         simple
# 2                                                NaN         simple
# 3  The net income is used as the numerator in the...         simple
# 4  The tax effects from share-based compensation ...         simple
#
#                                             metadata  episode_done
# 0  [{'source': 'data/meta10k.pdf', 'file_path': '...          True
# 1  [{'source': 'data/meta10k.pdf', 'file_path': '...          True
# 2  [{'source': 'data/meta10k.pdf', 'file_path': '...          True
# 3  [{'source': 'data/meta10k.pdf', 'file_path': '...          True
# 4  [{'source': 'data/meta10k.pdf', 'file_path': '...          True

# %%
test_questions = testset["question"].values.tolist()
test_groundtruths = testset["ground_truth"].values.tolist()

# %%
answers = []
contexts = []

for question in test_questions:
  response = chain.invoke({"question" : question})
  answers.append(response["answer"])
  contexts.append([context.page_content for context in response["source_documents"]])

# %%
print(answers)
# Out:
# ["The total value of 'Cash and cash equivalents' as of December 31, 2023, was $41.862 billion.", "The total value of 'Cash and cash equivalents' as of December 31, 2023, was $41.862 billion.", "The use of a common identifier can help in attributing multiple user accounts within and across products by providing a unique link or connection between different accounts that belong to the same individual. This common identifier allows for easier tracking and matching of accounts, making it more accurate to estimate the number of unique people using the products. However, in the context provided, it's mentioned that they do not require people to use a common identifier, so they rely on complex techniques, algorithms, and machine learning models to attribute multiple user accounts to individual people.", 'In the computation of diluted EPS, net income is adjusted for the effect of dilutive securities, such as restricted stock units (RSUs) awards under the Equity Incentive Plan. This adjustment includes reallocating net income as a result of the conversion of Class B to Class A common stock and any reallocation of net income to Class B common stock. The adjusted net income figure is then used in the calculation of diluted EPS.', 'Tax effects from share-based compensation can impact the effective tax rate significantly. The impact depends on factors such as the stock price at the time of employee award vesting. Differences between the share-based compensation expense and the deductions taken on the tax return, influenced by the stock price, can either increase or decrease the effective tax rate. For example, excess tax benefits recognized from share-based compensation can decrease the provision for income taxes and the effective income tax rate. Therefore, fluctuations in stock price and the accounting treatment of share-based compensation can lead to variations in the effective tax rate from period to period.', 'Earnings per share (EPS) using the two-class method is computed by dividing the net income by the weighted-average number of shares of Class A and Class B common stock outstanding. For the calculation of diluted EPS, net income for basic EPS is adjusted by the effect of dilutive securities, including restricted stock units (RSUs) awards. The diluted EPS of Class A common stock assumes the conversion of Class B common stock to Class A common stock, while the diluted EPS of Class B common stock does not assume the conversion. Diluted EPS is then computed by dividing the resulting net income by the weighted-average number of fully diluted common shares outstanding.', 'A decrease in user engagement can adversely affect advertising revenue in several ways. If users spend less time on the platform or engage less frequently, there will be fewer opportunities for ads to be displayed, reducing the overall ad impressions. This can lead to a decrease in the effectiveness of advertising campaigns and, consequently, a decrease in revenue for the platform. Additionally, lower user engagement may result in a decline in the attractiveness of the platform to marketers, leading to a potential loss of advertising partners and revenue.', "A PCAOB-registered public accounting firm plays a crucial role in expressing an opinion on a company's financial statements and internal control over financial reporting. Their responsibilities include conducting audits in accordance with PCAOB standards to obtain reasonable assurance about the accuracy of the financial statements and the effectiveness of internal controls. The firm assesses risks, tests the design and operating effectiveness of internal controls, and performs necessary procedures to evaluate the financial statements for material misstatements. Ultimately, the firm's opinion provides stakeholders with confidence in the reliability of the company's financial reporting.", 'Foreign currency transaction gains and losses from transactions denominated in a currency other than the functional currency of  ...

# %%
from datasets import Dataset
# convert test_questions to list of strings
# using list comprehension convert answers to list of strings


dict = {
    "question" : [str(t) for t in test_questions],
    "answer" : [str(answer) for answer in answers],
    "contexts" :contexts,
    "ground_truth" : [str(g) for g in test_groundtruths]
}
response_dataset = Dataset.from_dict(dict)
response_dataset[0]
# Out:
# {'question': "What was the total value of 'Cash and cash equivalents' as of December 31, 2023?",
#  'answer': "The total value of 'Cash and cash equivalents' as of December 31, 2023, was $41.862 billion.",
#  'contexts': ['Inputs\n(Level 3)\nCash\n$\n6,265\xa0\nCash equivalents:\nMoney market funds\n32,910\xa0\n$\n32,910\xa0\n$\n—\xa0\n$\n—\xa0\nU.S. government and agency securities\n2,206\xa0\n2,206\xa0\n—\xa0\n—\xa0\nTime deposits\n261\xa0\n—\xa0\n261\xa0\n—\xa0\nCorporate debt securities\n220\xa0\n—\xa0\n220\xa0\n—\xa0\nTotal cash and cash equivalents\n41,862\xa0\n35,116\xa0\n481\xa0\n—\xa0\nMarketable securities:\nU.S. government securities\n8,439\xa0\n8,439\xa0\n—\xa0\n—\xa0\nU.S. government agency securities\n3,498\xa0\n3,498\xa0\n—\xa0\n—\xa0\nCorporate debt securities\n11,604\xa0\n—\xa0\n11,604\xa0\n—\xa0\nTotal marketable securities\n23,541\xa0\n11,937\xa0\n11,604\xa0\n—\xa0\nRestricted cash equivalents\n857\xa0\n857\xa0\n—\xa0\n—\xa0\nOther assets\n101\xa0\n—\xa0\n—\xa0\n101\xa0\nTotal\n$\n66,361\xa0\n$\n47,910\xa0\n$\n12,085\xa0\n$\n101\xa0\n107',
#   '•\nCapital expenditures, including principal payments on finance leases, were $28.10\xa0billion for the year ended December\xa031, 2023.\n•\nEffective tax rate was 17.6% for the year ended December\xa031, 2023.\n•\nCash, cash equivalents, and marketable securities were $65.40\xa0billion as of December\xa031, 2023.\n•\nLong-term debt was $18.39\xa0billion as of December\xa031, 2023.\n•\nHeadcount was 67,317 as of December\xa031, 2023, a decrease of 22% year-over-year.\nDividend\nPrior to 2024, we had never declared or paid any cash dividend on our common stock. On February 1, 2024 we announced the initiation of our first ever\ncash dividend program. This cash dividend of $0.50 per share of Class A common stock and Class B common stock (together, the “common stock”) is\nequivalent to $2.00 per share on an annual basis. The first cash dividend will be paid on March\xa026, 2024 to all holders of record of common stock at the close\nof business on February\xa022, 2024.\n60',
#   'Table of Contents\n\xa0\n\xa0\nFair Value Measurement at Reporting Date Using\nDescription\nDecember 31, 2022\nQuoted\xa0Prices in Active\nMarkets for\nIdentical\xa0Assets\n(Level 1)\nSignificant Other\nObservable Inputs\n(Level 2)\nSignificant Unobservable\nInputs\n(Level 3)\nCash\n$\n6,176\xa0\nCash equivalents:\nMoney market funds\n8,305\xa0\n$\n8,305\xa0\n$\n—\xa0\n$\n—\xa0\nU.S. government and agency securities\n16\xa0\n16\xa0\n—\xa0\n—\xa0\nTime deposits\n156\xa0\n—\xa0\n156\xa0\n—\xa0\nCorporate debt securities\n28\xa0\n—\xa0\n28\xa0\n—\xa0\nTotal cash and cash equivalents\n14,681\xa0\n8,321\xa0\n184\xa0\n—\xa0\nMarketable securities:\nU.S. government securities\n8,708\xa0\n8,708\xa0\n—\xa0\n—\xa0\nU.S. government agency securities\n4,989\xa0\n4,989\xa0\n—\xa0\n—\xa0\nCorporate debt securities\n12,335\xa0\n—\xa0\n12,335\xa0\n—\xa0\nMarketable equity securities\n25\xa0\n25\xa0\n—\xa0\n—\xa0\nTotal marketable securities\n26,057\xa0\n13,722\xa0\n12,335\xa0\n—\xa0\nRestricted cash equivalents\n583\xa0\n583\xa0\n—\xa0\n—\xa0\nOther assets\n157\xa0\n—\xa0\n—\xa0\n157\xa0\nTotal\n$\n41,478\xa0\n$\n22,626\xa0\n$\n12,519\xa0\n$\n157\xa0\nUnrealized Losses',
#   'Table of Contents\nLiquidity and Capital Resources\nOur principal sources of liquidity are our cash, cash equivalents, marketable securities, and cash generated from operations. Cash, cash equivalents, and\nmarketable securities are comprised of cash on deposit with banks, time deposits, money market funds, U.S. government and agency securities, and investment\ngrade corporate debt securities. As part of our cash management strategy, we concentrate cash deposits with large financial institutions and our investment\nholdings are in diversified highly rated securities. Cash, cash equivalents, and marketable securities were $65.40\xa0billion as of December\xa031, 2023, an increase\nof $24.67\xa0billion from December\xa031, 2022. The increase was mostly due to $71.11\xa0billion of cash generated from operations, and $8.46 billion of net proceeds\nfrom the issuance of fixed-rate senior unsecured notes (the Notes) in May 2023. These increases were partially offset by $28.10 billion for capital expenditures,'],
#  'ground_truth': '$41.86B'}

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

results = evaluate(response_dataset, metrics)
# Out:
# Evaluating:  10%|█         | 7/70 [00:05<00:44,  1.40it/s]No statements were generated from the answer.
# Evaluating: 100%|██████████| 70/70 [00:26<00:00,  2.66it/s]

# %%
results_df = results.to_pandas()
results_df
# Out:
#                                              question  \
# 0   What was the total value of 'Cash and cash equ...
# 1   Who are Meta's 'Directors' (i.e., members of t...
# 2   How does the use of a common identifier help i...
# 3   How is net income used in the computation of d...
# 4   How does tax effects from share-based compensa...
# 5   How is earnings per share computed using the t...
# 6   How does a decrease in user engagement affect ...
# 7   What is the role of a PCAOB-registered public ...
# 8   How are foreign currency transaction gains and...
# 9   How does acting in the best interests of stock...
# 10  How are dilutive securities, such as restricte...
# 11  What documents are included in the Consolidate...
# 12  What role do assumptions play in the preparati...
# 13  What is the FTC's role in privacy compliance a...
#
#                                                answer  \
# 0   The total value of 'Cash and cash equivalents'...
# 1   The total value of 'Cash and cash equivalents'...
# 2   The use of a common identifier can help in att...
# 3   In the computation of diluted EPS, net income ...
# 4   Tax effects from share-based compensation can ...
# 5   Earnings per share (EPS) using the two-class m...
# 6   A decrease in user engagement can adversely af...
# 7   A PCAOB-registered public accounting firm play...
# 8   Foreign currency transaction gains and losses ...
# 9   Acting in the best interests of stockholders i...
# 10  Dilutive securities, such as restricted stock ...
# 11  The documents included in the Consolidated Fin...
# 12  Assumptions play a significant role in the pre...
# 13  The FTC (Federal Trade Commission) plays a sig...
#
#                                              contexts  \
# 0   [Inputs\n(Level 3)\nCash\n$\n6,265 \nCash equi...
# 1   [Inputs\n(Level 3)\nCash\n$\n6,265 \nCash equi...
# 2   [mobile browser on a given day. We do not requ...
# 3   [stock, while the diluted EPS of Class B commo...
# 4   [that period, our effective tax rate may be in...
# 5   [Table of Contents\nNote 4. Earnings per Share...
# 6   [Our advertising revenue can also be adversely...
# 7   [We also have audited, in accordance with the ...
# 8   [cumulative translation losses, net of tax of ...
# 9   [jurisdictions remain ongoing and could subjec...
# 10  [stock, while the diluted EPS of Class B commo...
# 11  [Table of Contents\nPART IV\nItem 15. Exhibit ...
# 12  [Table of Contents\nCritical Accounting Estima...
# 13  [Table of Contents\namong other things, requir...
#
#                                          ground_truth  faithfulness  \
# 0                                             $41.86B           1.0
# 1   The Directors of Meta Platforms, Inc. listed o...           NaN
# 2                                                 nan           1.0
# 3   The net income is used as the numerator in the...           1.0
# 4   The tax effects from share-based compensation ...           1.0
# 5   Earnings per share (EPS) using the two-class m...           1.0
# 6   A decrease in user engagement can adversely af...           1.0
# 7   The role of a PCAOB-registered public accounti...           1.0
# 8   Foreign currency transaction gains and losses ...           1.0
# 9   Mr. Zuckerberg, as a stockholder, is entitled ...           1.0
# 10  Dilutive securities, such as restricted stock ...           1.0
# 11  Consolidated Balance Sheets, Consolidated Stat...           1.0
# 12  Assumptions play a role in the preparation of ...           1.0
# 13  The FTC's role in privacy compliance is to mon...           1.0
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           1.000000             1.0           0.833333            0.712338
# 1           0.730223             1.0           0.750000            0.172698
# 2           0.956422             1.0           1.000000            0.177512
# 3           0.917511             1.0           1.000000            0.864918
# 4           0.965960             1.0           1.000000            0.983733
# 5           0.985632             1.0           1.000000            0.456826
# 6           0.991471             1.0           1.000000            0.486427
# 7           0.994390             1.0           1.000000            0.842494
# 8           0.990724             1.0           0.750000            0.749497
# 9           0.885007             1.0           0.500000            0.884206
# 10          0.942772             1.0           1.000000            0.745261
# 11          1.000000             1.0           1.000000            0.918266
# 12          1.000000             1.0           1.000000            0.573660
# 13          0.944970             1.0           1.000000            0.844588

# %%
results_df.to_csv("baseline.csv", index=False)

# %% [markdown]
# ### Now let's improve by chaining MultiQueryRetriever

# %%
from langchain.retrievers import MultiQueryRetriever
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain

def init2():
    loader = PyMuPDFLoader(
        "data/meta10k.pdf",
    )

    documents = loader.load()
    text=''
    for doc in documents:
        text+=doc.page_content
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=600, chunk_overlap=50)

    # Split the text into chunks
    documents = text_splitter.split_documents(documents)

    # Create a Chroma vector store
    embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

    # Create a Chroma vector store
    docsearch = Qdrant.from_documents(
        documents, embeddings, location=":memory:"
    )

    primary_qa_llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0, streaming=True)

    template = """Answer the question based only on the following context. 
    When answering about financial information, look for content only in table form.

    Context:
    {context}

    Question:
    {input}
    """

    prompt = ChatPromptTemplate.from_template(template)

    advanced_retriever = MultiQueryRetriever.from_llm(retriever=docsearch.as_retriever(), llm=primary_qa_llm)
    document_chain = create_stuff_documents_chain(primary_qa_llm, prompt)
    retrieval_chain = create_retrieval_chain(advanced_retriever, document_chain)

    return retrieval_chain

chain2 = init2()

# %%
res = chain2.invoke({"input" : "Who are Meta's 'Directors' (i.e., members of the Board of Directors) on the signature page?"})

print(res["answer"])
# Out:
# The Directors of Meta on the signature page are:
# - Aaron Anderson
# - Peggy Alford
# - Marc L. Andreessen
# - Andrew W. Houston
# - Nancy Killefer
# - Robert M. Kimmitt
# - Sheryl K. Sandberg
# - Tracey T. Travis
# - Tony Xu

# %%
for source in res["context"]:
    print(source.page_content)
    print('------------------')
# Out:
# Table of Contents
# SIGNATURES
# Pursuant to the requirements of Section 13 or 15(d) of the Securities Exchange Act of 1934, the Registrant has duly caused this Annual Report on Form
# 10-K to be signed on its behalf by the undersigned, thereunto duly authorized, in the City of Menlo Park, State of California, on this 1st day of February 2024.
# META PLATFORMS, INC.
# Date:
# February 1, 2024
# /s/ Susan Li
# Susan Li
# Chief Financial Officer
#
# 131
# ------------------
# Table of Contents
# PART III
# Item 10. Directors, Executive Officers and Corporate Governance
# The information required by this item is incorporated by reference to our Proxy Statement for the 2024 Annual Meeting of Stockholders to be filed with
# the SEC within 120 days of the fiscal year ended December 31, 2023.
# Our board of directors has adopted a Code of Conduct applicable to all officers, directors, and employees, which is available on our website
# ------------------
# on the Nasdaq Global Select Market under the symbol "META." Our principal executive offices are located at 1 Meta Way, Menlo Park, California 94025, and
# our telephone number is (650) 543-4800.
# Meta, the Meta logo, Meta Quest, Meta Horizon, Facebook, FB, Instagram, Oculus, WhatsApp, Reels, and our other registered or common law
# trademarks, service marks, or trade names appearing in this Annual Report on Form 10-K are the property of Meta Platforms, Inc. or its affiliates. Other
# ------------------
# to the Delaware General Corporation Law, our amended and restated certificate of incorporation or our amended and restated bylaws; or any action asserting a
# claim against us that is governed by the internal affairs doctrine.
# Listing
# Our Class A common stock is listed on the Nasdaq Global Select Market under the symbol “META.”
# Transfer Agent and Registrar
# The transfer agent and registrar for our common stock is Computershare Trust Company, N.A.
# 4
# ------------------
# Aaron Anderson
# /s/ Peggy Alford
# Director
# February 1, 2024
# Peggy Alford
# /s/ Marc L. Andreessen
# Director
# February 1, 2024
# Marc L. Andreessen
# /s/ Andrew W. Houston
# Director
# February 1, 2024
# Andrew W. Houston
# /s/ Nancy Killefer
# Director
# February 1, 2024
# Nancy Killefer
# /s/ Robert M. Kimmitt
# Director
# February 1, 2024
# Robert M. Kimmitt
# /s/ Sheryl K. Sandberg
# Director
# February 1, 2024
# Sheryl K. Sandberg
# /s/ Tracey T. Travis
# Director
# February 1, 2024
# Tracey T. Travis
# /s/ Tony Xu
# Director
# February 1, 2024
# Tony Xu
# 132
# ------------------
# affect our business.
# For additional information about government regulation applicable to our business, see Part I, Item 1A, "Risk Factors" in this Annual Report on Form
# 10-K.
# Human Capital
# At Meta, everything we do is about helping people feel connected and closer, and we are proud of our unique company culture.
# We had a global workforce of 67,317 employees as of December 31, 2023, and we have offices in approximately 90 cities around the world. We are
# ------------------
# 10-K
# 001-35551
# 4.1
# February 3, 2022
# 4.2
# Form of Class B Common Stock Certificate.
# 10-K
# 001-35551
# 4.2
# February 3, 2022
# 4.3
# Indenture, dated as of August 9, 2022, between Meta
# Platforms, Inc. and U.S. Bank Trust Company,
# National Association, as trustee.
# 8-K
# 001-35551
# 4.1
# August 9, 2022
# 4.4
# First Supplemental Indenture, dated as of August 9,
# 2022, between Meta Platforms, Inc. and U.S. Bank
# Trust Company, National Association, as trustee.
# 8-K
# 001-35551
# 4.2
# August 9, 2022
# 4.5
# Second Supplemental Indenture, dated as of May 3,
# 2023, by and between Meta Platforms, Inc. and U.S.
# ------------------

# %%
res = chain2.invoke({"input" : "What was the total value of 'Cash and cash equivalents' as of December 31, 2023?"})

print(res["answer"])
# Out:
# The total value of 'Cash and cash equivalents' as of December 31, 2023 was $41,381 million.

# %%
answers = []
contexts = []

for question in test_questions:
  response = chain2.invoke({"input" : question})
  print(response["answer"])
  answers.append(response["answer"])
  contexts.append([context.page_content for context in response["context"]])
# Out:
# The total value of 'Cash and cash equivalents' as of December 31, 2023 was $41,381 million.
# The information required to answer this question is not present in the provided context.
# Based on the context provided, the use of a common identifier is not required to attribute multiple user accounts within and across products in the Family metrics. The calculations rely on complex techniques, algorithms, and machine learning models to estimate the number of unique people using the products, including matching user accounts without the need for a common identifier.
# Net income for the computation of diluted EPS is adjusted by the effect of dilutive securities, including restricted stock units (RSUs) awards under the Equity Incentive Plan. Additionally, the net income is reallocated as a result of the conversion of Class B to Class A common stock.
# Based on the context provided, the tax effects from share-based compensation can impact the effective tax rate significantly, sometimes from period to period. The impact depends on the difference between the share-based compensation expense and the deductions taken on the tax return, which are influenced by the stock price at the time of employee award vesting. Excess tax benefits or shortfalls from share-based compensation can also impact the effective tax rate.
# Earnings per share is computed using the two-class method by dividing net income by the weighted-average number of shares of Class A and Class B common stock outstanding.
# A decrease in user engagement could render our products less attractive to users, marketers, and developers, which is likely to have a material and adverse impact on our ability to deliver ad impressions and, accordingly, our revenue, business, financial condition, and results of operations.
# Based on the context provided, the role of a PCAOB-registered public accounting firm in expressing an opinion on a company's financial statements and internal control over financial reporting is to conduct audits in accordance with PCAOB standards to obtain reasonable assurance about the reliability of the financial reporting and the preparation of financial statements. The firm is responsible for assessing the risks of material misstatement in the financial statements, whether due to error or fraud, and performing procedures to respond to those risks. Additionally, the firm is required to be independent with respect to the company in accordance with U.S. federal securities laws and regulations.
# Foreign currency transaction gains and losses from transactions denominated in a currency other than the functional currency of the subsidiary involved are recorded within interest and other income (expense), net on the consolidated statements of income.
# This question cannot be answered based on the provided context as it does not contain any financial information in table form.
# Dilutive securities, such as restricted stock units (RSUs), are taken into account in the calculation of diluted EPS by adjusting the net income for basic EPS to account for the effect of dilutive securities. This adjustment includes excluding certain RSUs from the diluted EPS calculation if they would have an anti-dilutive effect. The diluted EPS is then computed by dividing the resulting adjusted net income by the weighted-average number of fully diluted common shares outstanding.
# The documents included in the Consolidated Financial Statements section of the Form 10-K are:
# - Reports of Independent Registered Public Accounting Firm
# - Consolidated Balance Sheets
# - Consolidated Statements of Income
# - Consolidated Statements of Comprehensive Income
# - Consolidated Statements of Stockholders' Equity
# - Consolidated Statements of Cash Flows
# - Notes to Consolidated Financial Statements
# Assumptions play a significant role in the preparation of consolidated financial statements as they are used to make estimates that affect the reported amounts of assets, liabilities, revenue, costs and expenses, and related disclosures. These estimates form the basis for judgments about the carrying values of assets and liabilities that are not readily apparent from other sources. Assumptions are based on historical information and various other reasonable assumptions under the circumstances.
# The FTC's role in privacy compliance and addressing privacy law violations, including COPPA, the COPPA Rule, and Section 5 of the FTC Act, involves monitoring compliance with consent orders, initiating administrative proceedings against companies for alleged violations, and seeking changes to business practices through proposed orders.

# %%
test_groundtruths[0]=''

# %%
from datasets import Dataset

dict = {
    "question" : [str(t) for t in test_questions],
    "answer" : [str(answer) for answer in answers],
    "contexts" :contexts,
    "ground_truth" : [str(g) for g in test_groundtruths]
}
response_dataset = Dataset.from_dict(dict)
response_dataset[0]
# Out:
# {'question': "What was the total value of 'Cash and cash equivalents' as of December 31, 2023?",
#  'answer': "The total value of 'Cash and cash equivalents' as of December 31, 2023 was $41,381 million.",
#  'contexts': ['Table of Contents\n\xa0\n\xa0\nFair Value Measurement at Reporting Date Using\nDescription\nDecember 31, 2022\nQuoted\xa0Prices in Active\nMarkets for\nIdentical\xa0Assets\n(Level 1)\nSignificant Other\nObservable Inputs\n(Level 2)\nSignificant Unobservable\nInputs\n(Level 3)\nCash\n$\n6,176\xa0\nCash equivalents:\nMoney market funds\n8,305\xa0\n$\n8,305\xa0\n$\n—\xa0\n$\n—\xa0\nU.S. government and agency securities\n16\xa0\n16\xa0\n—\xa0\n—\xa0\nTime deposits\n156\xa0\n—\xa0\n156\xa0\n—\xa0\nCorporate debt securities\n28\xa0\n—\xa0\n28\xa0\n—\xa0\nTotal cash and cash equivalents\n14,681\xa0\n8,321\xa0\n184\xa0\n—\xa0\nMarketable securities:\nU.S. government securities\n8,708\xa0\n8,708\xa0\n—\xa0\n—',
#   '$\n42,827\xa0\n$\n15,596\xa0\n$\n16,865\xa0\nReconciliation of cash, cash equivalents, and restricted cash to the consolidated balance\nsheets\nCash and cash equivalents\n$\n41,862\xa0\n$\n14,681\xa0\n$\n16,601\xa0\nRestricted cash, included in prepaid expenses and other current assets\n99\xa0\n294\xa0\n149\xa0\nRestricted cash, included in other assets\n866\xa0\n621\xa0\n115\xa0\nTotal cash, cash equivalents, and restricted cash\n$\n42,827\xa0\n$\n15,596\xa0\n$\n16,865\xa0\n\xa0\xa0\xa0\xa0\nSee Accompanying Notes to Consolidated Financial Statements.\n93',
#   'were $366\xa0million, $81\xa0million, and $140\xa0million for the years ended December\xa031, 2023, 2022, and 2021, respectively.\nCredit Risk and Concentration\nOur financial instruments that are potentially subject to concentrations of credit risk consist primarily of cash, cash equivalents, restricted cash,\nmarketable securities, and accounts receivable. Cash equivalents consists mostly of money market funds, that primarily invest in U.S. government and agency',
#   'holdings are in diversified highly rated securities. Cash, cash equivalents, and marketable securities were $65.40\xa0billion as of December\xa031, 2023, an increase\nof $24.67\xa0billion from December\xa031, 2022. The increase was mostly due to $71.11\xa0billion of cash generated from operations, and $8.46 billion of net proceeds\nfrom the issuance of fixed-rate senior unsecured notes (the Notes) in May 2023. These increases were partially offset by $28.10 billion for capital expenditures,',
#   'The following tables summarize our assets measured at fair value on a recurring basis and the classification by level of input within the fair value\nhierarchy (in millions):\n\xa0\n\xa0\nFair Value Measurement at Reporting Date Using\nDescription\nDecember 31, 2023\nQuoted\xa0Prices in Active\nMarkets for\nIdentical\xa0Assets\n(Level 1)\nSignificant Other\nObservable Inputs\n(Level 2)\nSignificant Unobservable\nInputs\n(Level 3)\nCash\n$\n6,265\xa0\nCash equivalents:\nMoney market funds\n32,910\xa0\n$\n32,910\xa0\n$\n—\xa0\n$\n—\xa0\nU.S. government and agency securities\n2,206\xa0\n2,206\xa0\n—\xa0\n—\xa0\nTime deposits\n261\xa0\n—\xa0\n261\xa0\n—\xa0\nCorporate debt securities'],
#  'ground_truth': '$41.86B'}

# %%
from ragas import evaluate
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_correctness,
    context_recall,
    context_precision,
)

metrics = [
    faithfulness,
    answer_relevancy,
    context_recall,
    context_precision,
    answer_correctness,
]

results = evaluate(response_dataset, metrics)
results_df = results.to_pandas()
results_df
# Out:
# Evaluating:   0%|          | 0/70 [00:00<?, ?it/s]No statements were generated from the answer.
# Evaluating:  39%|███▊      | 27/70 [00:11<00:11,  3.65it/s]No statements were generated from the answer.
# Evaluating: 100%|██████████| 70/70 [00:32<00:00,  2.18it/s]
#                                              question  \
# 0   What was the total value of 'Cash and cash equ...
# 1   Who are Meta's 'Directors' (i.e., members of t...
# 2   How does the use of a common identifier help i...
# 3   How is net income used in the computation of d...
# 4   How does tax effects from share-based compensa...
# 5   How is earnings per share computed using the t...
# 6   How does a decrease in user engagement affect ...
# 7   What is the role of a PCAOB-registered public ...
# 8   How are foreign currency transaction gains and...
# 9   How does acting in the best interests of stock...
# 10  How are dilutive securities, such as restricte...
# 11  What documents are included in the Consolidate...
# 12  What role do assumptions play in the preparati...
# 13  What is the FTC's role in privacy compliance a...
#
#                                                answer  \
# 0   The total value of 'Cash and cash equivalents'...
# 1   The information required to answer this questi...
# 2   Based on the context provided, the use of a co...
# 3   Net income for the computation of diluted EPS ...
# 4   Based on the context provided, the tax effects...
# 5   Earnings per share is computed using the two-c...
# 6   A decrease in user engagement could render our...
# 7   Based on the context provided, the role of a P...
# 8   Foreign currency transaction gains and losses ...
# 9   This question cannot be answered based on the ...
# 10  Dilutive securities, such as restricted stock ...
# 11  The documents included in the Consolidated Fin...
# 12  Assumptions play a significant role in the pre...
# 13  The FTC's role in privacy compliance and addre...
#
#                                              contexts  \
# 0   [Table of Contents\n \n \nFair Value Measureme...
# 1   [on the Nasdaq Global Select Market under the ...
# 2   [therefore must seek to attribute multiple use...
# 3   [the calculation of diluted EPS, net income fo...
# 4   [the tax rate without such benefits. In future...
# 5   [Table of Contents\nNote 4. Earnings per Share...
# 6   [reduce our ability to effectively target ads,...
# 7   [to express an opinion on the Company's intern...
# 8   [losses are recorded in accumulated other comp...
# 9   [fiduciary duty to our stockholders and must a...
# 10  [the calculation of diluted EPS, net income fo...
# 11  [Table of Contents\nPART IV\nItem 15. Exhibit ...
# 12  [Table of Contents\nCritical Accounting Estima...
# 13  [Table of Contents\namong other things, requir...
#
#                                          ground_truth  faithfulness  \
# 0                                             $41.86B           0.0
# 1   The Directors of Meta Platforms, Inc. listed o...           NaN
# 2                                                 nan           1.0
# 3   The net income is used as the numerator in the...           1.0
# 4   The tax effects from share-based compensation ...           1.0
# 5   Earnings per share (EPS) using the two-class m...           1.0
# 6   A decrease in user engagement can adversely af...           1.0
# 7   The role of a PCAOB-registered public accounti...           1.0
# 8   Foreign currency transaction gains and losses ...           1.0
# 9   Mr. Zuckerberg, as a stockholder, is entitled ...           NaN
# 10  Dilutive securities, such as restricted stock ...           1.0
# 11  Consolidated Balance Sheets, Consolidated Stat...           1.0
# 12  Assumptions play a role in the preparation of ...           1.0
# 13  The FTC's role in privacy compliance is to mon...           1.0
#
#     answer_relevancy  context_recall  context_precision  answer_correctness
# 0           1.000000             1.0           0.866667            0.710426
# 1           0.000000             1.0           0.926667            0.174213
# 2           0.834123             1.0           0.000000            0.178565
# 3           0.947057             1.0           1.000000            0.823252
# 4           0.994948             1.0           0.833333            0.535367
# 5           0.927420             1.0           1.000000            0.617972
# 6           0.943740             1.0           0.966667            0.738696
# 7           1.000000             1.0           1.000000            0.619468
# 8           0.990729             1.0           0.976190            0.749497
# 9           0.000000             1.0           1.000000            0.185185
# 10          1.000000             1.0           1.000000            0.459574
# 11          1.000000             1.0           1.000000            0.917268
# 12          1.000000             1.0           1.000000            0.674983
# 13          0.952514             1.0           1.000000            0.846996

# %%
results_df.to_csv("advanced.csv", index=False)

# %%
baseline = pd.read_csv("baseline.csv")
advanced = pd.read_csv("advanced.csv")
# merge the two dataframes
merged = pd.merge(baseline, advanced, on="question", suffixes=("_baseline", "_advanced"))

# from the baseline, get columns named "faithfulness", "answer_relevancy", "context_recall", "context_precision", "answer_correctness"
metrics = ["faithfulness", "answer_relevancy", "context_recall", "context_precision", "answer_correctness"]
baseline_columns = [f"{metric}_baseline" for metric in metrics]
# from the advanced, get columns named "faithfulness", "answer_relevancy", "context_recall", "context_precision", "answer_correctness"
advanced_columns = [f"{metric}_advanced" for metric in metrics]

# convert columns to rows in baseline_columns
delta = pd.DataFrame()
for metric in metrics:
    delta[metric] = merged[f"{metric}_advanced"] - merged[f"{metric}_baseline"]
delta.mean()

# calculate the difference between the advanced and baseline
# Out:
# faithfulness         -0.083333
# answer_relevancy     -0.122468
# context_recall        0.000000
# context_precision    -0.018844
# answer_correctness   -0.084354
# dtype: float64
